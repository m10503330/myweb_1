# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df=pd.read_csv("air.csv")
df=df.drop(0)
df=df.dropna(axis=1)
max_data=df[df['X']==df.loc[df['U'].idxmax()]['X']]
print("最大X方向速度U的描述")
max_data.describe()
plt.plot(max_data['U'],"o")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-468742a9ceac> in <module>()
#       4
#       5
# ----> 6 df=pd.read_csv("air.csv")
#       7 df=df.drop(0)
#       8 df=df.dropna(axis=1)
#
# ...
